# %%
import pandas as pd
import json

# %%
path_training_res = "./training_res.csv"
df_training_res = pd.read_csv(path_training_res)
path_analysis_res = "../../datasets_analysis.csv"
df_analysis_res = pd.read_csv(path_analysis_res)
df_ds = df_analysis_res[["ds_name", "test_classes_distr"]]
df_ds["max_dist_val"] = df_ds.apply(lambda row: max(json.loads(row["test_classes_distr"]).values()), axis=1)
df_training_res_with_dist = pd.merge(df_training_res, df_ds, right_on="ds_name", left_on="dataset_name")
df_training_res_with_dist = df_training_res_with_dist[["dataset_name", "model_name", "test_acc", "max_dist_val"]]
df_training_res_with_dist["diff"] = df_training_res_with_dist.apply(lambda row: round(row["test_acc"], 2) != round(row["max_dist_val"], 2), axis=1)
# Out:
# /scratch/slurm_tmpdir/job_21663083/ipykernel_217996/2544370308.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ds["max_dist_val"] = df_ds.apply(lambda row: max(json.loads(row["test_classes_distr"]).values()), axis=1)

# %%
df_training_res_with_dist
# Out:
#                   dataset_name model_name  test_acc  max_dist_val   diff
# 0           abnormal_heartbeat    Encoder  0.726829      0.731707  False
# 1   phalanges_outlines_correct    Encoder  0.755245      0.613054   True
# 2                 swedish_leaf    Encoder  0.915200      0.078400   True
# 3         share_price_increase    Encoder  0.687371      0.686335  False
# 4       distal_phalanx_outline    Encoder  0.735507      0.583333   True
# 5             electric_devices    Encoder  0.691739      0.253664   True
# 6                     freezers    Encoder  0.940702      0.500000   True
# 7                    cricket_y    Encoder  0.502564      0.094872   True
# 8                 coffee_beans    Encoder  0.642857      0.535714   True
# 9                   arrow_head    Encoder  0.640000      0.394286   True
# 10                       wafer    Encoder  0.993348      0.892116   True
