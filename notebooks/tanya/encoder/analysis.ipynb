# %%
import pandas as pd
import json

# %%
path_training_res = "./training_res.csv"
df_training_res = pd.read_csv(path_training_res)
path_analysis_res = "../../datasets_analysis.csv"
df_analysis_res = pd.read_csv(path_analysis_res)
df_ds = df_analysis_res[["ds_name", "test_classes_dist"]]
df_ds["max_dist_val"] = df_ds.apply(lambda row: max(json.loads(row["test_classes_dist"]).values()), axis=1)
df_training_res_with_dist = pd.merge(df_training_res, df_ds, right_on="ds_name", left_on="dataset_name")
df_training_res_with_dist = df_training_res_with_dist[["dataset_name", "model_name", "test_acc", "max_dist_val"]]
df_training_res_with_dist["diff"] = df_training_res_with_dist.apply(lambda row: round(row["test_acc"], 2) != round(row["max_dist_val"], 2), axis=1)
# Out:
# /scratch/slurm_tmpdir/job_21675981/ipykernel_244081/268053030.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ds["max_dist_val"] = df_ds.apply(lambda row: max(json.loads(row["test_classes_dist"]).values()), axis=1)

# %%
df_training_res_with_dist
# Out:
#                   dataset_name model_name  test_acc  max_dist_val   diff
# 0                          cbf    Encoder  0.855556      0.335556   True
# 1        gun_point_male_female    Encoder  0.984177      0.525316   True
# 2                          car    Encoder  0.683333      0.316667   True
# 3           abnormal_heartbeat    Encoder  0.746341      0.731707   True
# 4           distal_phalanax_tw    Encoder  0.676259      0.302158   True
# 5   phalanges_outlines_correct    Encoder  0.709790      0.613054   True
# 6                 swedish_leaf    Encoder  0.918400      0.078400   True
# 7         share_price_increase    Encoder  0.667702      0.686335   True
# 8       distal_phalanx_outline    Encoder  0.786232      0.583333   True
# 9                   strawberry    Encoder  0.948649      0.643243   True
# 10                 earthquakes    Encoder  0.748201      0.748201  False
# 11            electric_devices    Encoder  0.705356      0.253664   True
# 12                 fifty_words    Encoder  0.520879      0.125275   True
# 13                    freezers    Encoder  0.943509      0.500000   True
# 14           synthetic_control    Encoder  0.826667      0.166667   True
# 15          gun_point_age_span    Encoder  0.908228      0.506329   True
# 16                       trace    Encoder  0.820000      0.290000   True
# 17                        fish    Encoder  0.822857      0.165714   True
# 18    middle_phalanx_age_group    Encoder  0.597403      0.571429   True
# 19                 lightning_7    Encoder  0.410959      0.260274   True
# 20                  colposcopy    Encoder  0.277228      0.277228  False
# 21                   cricket_y    Encoder  0.515385      0.094872   True
# 22                coffee_beans    Encoder  0.535714      0.535714  False
# 23         gun_point_old_young    Encoder  0.939683      0.523810   True
# 24      middle_phalanx_correct    Encoder  0.780069      0.570447   True
# 25                         bme    Encoder  0.780000      0.333333   True
# 26                       plane    Encoder  0.980952      0.200000   True
# 27                  power_cons    Encoder  0.883333      0.500000   True
# 28                    face_ucr    Encoder  0.801463      0.143415   True
# 29              medical_images    Encoder  0.711842      0.514474   True
# 30      chlorine_concentration    Encoder  0.554688      0.532552   True
# 31             dodger_loop_day    Encoder  0.150000      0.162500   True
# 32                  arrow_head    Encoder  0.605714      0.394286   True

# %%
path_training_res = "./training_res.csv"
df_training_res = pd.read_csv(path_training_res)
path_analysis_res = "../../datasets_analysis.csv"
df_analysis_res = pd.read_csv(path_analysis_res)
df_ds = df_analysis_res[["ds_name", "test_classes_dist"]]
df_ds["max_dist_val"] = df_ds.apply(lambda row: max(json.loads(row["test_classes_dist"]).values()), axis=1)
df_training_res_with_dist = pd.merge(df_training_res, df_ds, right_on="ds_name", left_on="dataset_name")
df_training_res_with_dist = df_training_res_with_dist[["dataset_name", "model_name", "test_acc", "max_dist_val"]]
df_training_res_with_dist["diff"] = df_training_res_with_dist.apply(lambda row: round(row["test_acc"], 2) > round(row["max_dist_val"], 2) + 0.1, axis=1)
# Out:
# /scratch/slurm_tmpdir/job_21675981/ipykernel_244081/3587305007.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ds["max_dist_val"] = df_ds.apply(lambda row: max(json.loads(row["test_classes_dist"]).values()), axis=1)

# %%
df_training_res_with_dist[df_training_res_with_dist["diff"]==True]
# Out:
#               dataset_name model_name  test_acc  max_dist_val  diff
# 0                      cbf    Encoder  0.855556      0.335556  True
# 1    gun_point_male_female    Encoder  0.984177      0.525316  True
# 2                      car    Encoder  0.683333      0.316667  True
# 4       distal_phalanax_tw    Encoder  0.676259      0.302158  True
# 6             swedish_leaf    Encoder  0.918400      0.078400  True
# 8   distal_phalanx_outline    Encoder  0.786232      0.583333  True
# 9               strawberry    Encoder  0.948649      0.643243  True
# 11        electric_devices    Encoder  0.705356      0.253664  True
# 12             fifty_words    Encoder  0.520879      0.125275  True
# 13                freezers    Encoder  0.943509      0.500000  True
# 14       synthetic_control    Encoder  0.826667      0.166667  True
# 15      gun_point_age_span    Encoder  0.908228      0.506329  True
# 16                   trace    Encoder  0.820000      0.290000  True
# 17                    fish    Encoder  0.822857      0.165714  True
# 19             lightning_7    Encoder  0.410959      0.260274  True
# 21               cricket_y    Encoder  0.515385      0.094872  True
# 23     gun_point_old_young    Encoder  0.939683      0.523810  True
# 24  middle_phalanx_correct    Encoder  0.780069      0.570447  True
# 25                     bme    Encoder  0.780000      0.333333  True
# 26                   plane    Encoder  0.980952      0.200000  True
# 27              power_cons    Encoder  0.883333      0.500000  True
# 28                face_ucr    Encoder  0.801463      0.143415  True
# 29          medical_images    Encoder  0.711842      0.514474  True
# 32              arrow_head    Encoder  0.605714      0.394286  True

# %%
len(df_training_res_with_dist[df_training_res_with_dist["diff"]==True])
# Out:
# 24
