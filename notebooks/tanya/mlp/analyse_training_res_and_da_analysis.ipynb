# %%
import pandas as pd
import json

# %%
path_training_res = "./training_res.csv"
df_training_res = pd.read_csv(path_training_res)
path_analysis_res = "../../datasets_analysis.csv"
df_analysis_res = pd.read_csv(path_analysis_res)
df_ds = df_analysis_res[["ds_name", "test_classes_dist"]]
df_ds["max_dist_val"] = df_ds.apply(lambda row: max(json.loads(row["test_classes_dist"]).values()), axis=1)
df_training_res_with_dist = pd.merge(df_training_res, df_ds, right_on="ds_name", left_on="dataset_name")
df_training_res_with_dist = df_training_res_with_dist[["dataset_name", "model_name", "test_acc", "max_dist_val"]]
df_training_res_with_dist["diff"] = df_training_res_with_dist.apply(lambda row: round(row["test_acc"], 2) != round(row["max_dist_val"], 2), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 path_training_res = "./training_res.csv"
# ----> 2 df_training_res = pd.read_csv(path_training_res)
#       3 path_analysis_res = "../../datasets_analysis.csv"
#       4 df_analysis_res = pd.read_csv(path_analysis_res)
#
# NameError: name 'pd' is not defined

# %%
df_training_res_with_dist
# Out:
#                   dataset_name model_name  test_acc  max_dist_val   diff
# 0                          cbf        MLP  0.817778      0.335556   True
# 1        gun_point_male_female        MLP  0.525316      0.525316  False
# 2                          car        MLP  0.750000      0.316667   True
# 3           abnormal_heartbeat        MLP  0.731707      0.731707  False
# 4           distal_phalanax_tw        MLP  0.647482      0.302158   True
# 5   phalanges_outlines_correct        MLP  0.628205      0.613054   True
# 6                 swedish_leaf        MLP  0.688000      0.078400   True
# 7         share_price_increase        MLP  0.691511      0.686335  False
# 8       distal_phalanx_outline        MLP  0.659420      0.583333   True
# 9                   strawberry        MLP  0.862162      0.643243   True
# 10                 earthquakes        MLP  0.733813      0.748201   True
# 11            electric_devices        MLP  0.580859      0.253664   True
# 12                 fifty_words        MLP  0.648352      0.125275   True
# 13                    freezers        MLP  0.761404      0.500000   True
# 14           synthetic_control        MLP  0.790000      0.166667   True
# 15          gun_point_age_span        MLP  0.506329      0.506329  False
# 16                       trace        MLP  0.560000      0.290000   True
# 17                        fish        MLP  0.657143      0.165714   True
# 18    middle_phalanx_age_group        MLP  0.603896      0.571429   True
# 19                 lightning_7        MLP  0.602740      0.260274   True
# 20                  colposcopy        MLP  0.297030      0.277228   True
# 21                   cricket_y        MLP  0.487179      0.094872   True
# 22                coffee_beans        MLP  0.571429      0.535714   True
# 23         gun_point_old_young        MLP  0.476190      0.523810   True
# 24      middle_phalanx_correct        MLP  0.580756      0.570447   True
# 25                         bme        MLP  0.600000      0.333333   True
# 26                       plane        MLP  0.942857      0.200000   True
# 27                  power_cons        MLP  0.872222      0.500000   True
# 28                    face_ucr        MLP  0.698537      0.143415   True
# 29              medical_images        MLP  0.607895      0.514474   True
# 30      chlorine_concentration        MLP  0.552344      0.532552   True
# 31             dodger_loop_day        MLP  0.150000      0.162500   True
# 32                  arrow_head        MLP  0.577143      0.394286   True

# %%
path_training_res = "./training_res.csv"
df_training_res = pd.read_csv(path_training_res)
path_analysis_res = "../../datasets_analysis.csv"
df_analysis_res = pd.read_csv(path_analysis_res)
df_ds = df_analysis_res[["ds_name", "test_classes_dist"]]
df_ds["max_dist_val"] = df_ds.apply(lambda row: max(json.loads(row["test_classes_dist"]).values()), axis=1)
df_training_res_with_dist = pd.merge(df_training_res, df_ds, right_on="ds_name", left_on="dataset_name")
df_training_res_with_dist = df_training_res_with_dist[["dataset_name", "model_name", "test_acc", "max_dist_val"]]
df_training_res_with_dist["diff"] = df_training_res_with_dist.apply(lambda row: round(row["test_acc"], 2) > round(row["max_dist_val"], 2) + 0.1, axis=1)
# Out:
# /scratch/slurm_tmpdir/job_21674073/ipykernel_342831/3587305007.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ds["max_dist_val"] = df_ds.apply(lambda row: max(json.loads(row["test_classes_dist"]).values()), axis=1)

# %%
df_training_res_with_dist[df_training_res_with_dist["diff"]==True]
# Out:
#           dataset_name model_name  test_acc  max_dist_val  diff
# 0                  cbf        MLP  0.817778      0.335556  True
# 2                  car        MLP  0.750000      0.316667  True
# 4   distal_phalanax_tw        MLP  0.647482      0.302158  True
# 6         swedish_leaf        MLP  0.688000      0.078400  True
# 9           strawberry        MLP  0.862162      0.643243  True
# 11    electric_devices        MLP  0.580859      0.253664  True
# 12         fifty_words        MLP  0.648352      0.125275  True
# 13            freezers        MLP  0.761404      0.500000  True
# 14   synthetic_control        MLP  0.790000      0.166667  True
# 16               trace        MLP  0.560000      0.290000  True
# 17                fish        MLP  0.657143      0.165714  True
# 19         lightning_7        MLP  0.602740      0.260274  True
# 21           cricket_y        MLP  0.487179      0.094872  True
# 25                 bme        MLP  0.600000      0.333333  True
# 26               plane        MLP  0.942857      0.200000  True
# 27          power_cons        MLP  0.872222      0.500000  True
# 28            face_ucr        MLP  0.698537      0.143415  True
# 32          arrow_head        MLP  0.577143      0.394286  True

# %%
len(df_training_res_with_dist[df_training_res_with_dist["diff"]==True])
# Out:
# 18
